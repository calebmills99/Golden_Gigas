# %% [markdown]
# # 🌟 The Golden Girls Present: Understanding npm in 2026 🌟
#
# ## Episode: "The One Where Dorothy Learns Package Management"
#
# ### Season 42, Episode 7
#
# *Set in Miami, 2026. The girls have discovered that their retirement community needs a new website, and Dorothy has volunteered to learn web development. What could possibly go wrong?*
#
# *2026 status update: Miami has flying scooters, the fridge has Wi‑Fi, and Trump's newest campaign slogan is on its fifth semantic version this week.*

# %%
# 🔑 Stability AI API Key Setup
# Enter your API key below - we'll use it later to generate comic-style images of our favorite ladies!

import getpass

stability_api_key = getpass.getpass("Enter your Stability AI API key: ")
print("✅ API key saved! (We'll use this later for character images)")

# %%
# 🎨 Stability AI image generation helper (do not run by default)
# This defines a reusable function you can call later to create comic-style images.
# It does NOT call the API unless you explicitly run generate_stability_image(...).
#
# Setup tip: install requests before uncommenting (pip install requests)
#
# import os
# import requests
#
# def generate_stability_image(prompt, out_path, *, width=1024, height=1024, style_preset="comic-book"):
#     os.makedirs("images", exist_ok=True)
#     url = "https://api.stability.ai/v2beta/stable-image/generate/sd3"
#     headers = {
#         "Authorization": f"Bearer {stability_api_key}",
#         "Accept": "image/*",
#     }
#     data = {
#         "prompt": prompt,
#         "output_format": "png",
#         "width": width,
#         "height": height,
#         "style_preset": style_preset,
#     }
#     try:
#         response = requests.post(url, headers=headers, data=data, files={}, timeout=60)
#         response.raise_for_status()
#     except requests.RequestException as exc:
#         print(f"Stability API request failed: {exc}")
#         raise
#     with open(out_path, "wb") as f:
#         f.write(response.content)
#     return out_path

# %% [markdown]
# ---
#
# ## 🏠 Act 1: The Kitchen Table Confusion
#
# *[INT. KITCHEN - MORNING]*
#
# *Dorothy sits at the kitchen table, laptop open, looking frustrated. Rose enters with a plate of what appears to be a questionable casserole.*

# %% [markdown]
# ### 📸 Character Image Placeholder: Dorothy Looking Confused
#
# *[Comic-style image will appear here: Dorothy Zbornak staring at laptop with bewildered expression, glasses askew]*
#
# ```
# ┌─────────────────────────────────────┐
# │                                     │
# │    🧑‍🦳 DOROTHY AT LAPTOP 💻          │
# │                                     │
# │    [Confused Expression]            │
# │    "What's an npm??"                │
# │                                     │
# └─────────────────────────────────────┘
# ```

# %%
# Example (commented out): generate Dorothy image
# generate_stability_image(
#     "Comic-book style illustration of Dorothy Zbornak at a kitchen table, confused at a laptop, 2026 Miami morning light, expressive face, bright colors",
#     "images/dorothy_confused.png"
# )

# %% [markdown]
# **DOROTHY:** "I don't understand. I need to build a website, but this tutorial keeps talking about 'npm' and 'packages.' Why can't I just write the code myself?"
#
# **ROSE:** "Oh, that's easy, Dorothy! npm stands for 'Nice Produce Management.' Back in St. Olaf, we used npm to organize our—"
#
# **DOROTHY:** "Rose, it stands for Node Package Manager."
#
# **ROSE:** "Well, that makes more sense than my St. Olaf story about the time we..."
#
# *[Sophia enters]*
#
# **SOPHIA:** "What's all this racket? I'm trying to watch my stories!"
#
# **DOROTHY:** "Ma, I'm trying to learn about npm, but I don't understand why I need it."
#
# **SOPHIA:** "Picture it: Sicily, 1922. My mother needed to make cannoli for the whole village. Did she make everything from scratch? No! She borrowed Maria's ricotta, Giuseppe's chocolate chips, and Tony's pastry shells. That's npm, pussycat. You borrow other people's code so you don't reinvent the wheel."
#
# **DOROTHY:** "Ma, that's... actually helpful. Thank you."

# %% [markdown]
# ---
#
# ## 📦 What IS npm?
#
# npm (Node Package Manager) is the world's largest software registry. It allows developers to:
#
# - **Share** code packages with other developers
# - **Reuse** code from other developers
# - **Manage** project dependencies
# - **Version control** packages
#
# Think of it like Sophia's Sicily story: instead of building everything from scratch, you can use pre-built packages that others have created and tested!

# %% [markdown]
# ### 📸 Character Image Placeholder: Sophia Telling a Story
#
# *[Comic-style image will appear here: Sophia Petrillo gesturing animatedly, clutching her purse]*
#
# ```
# ┌─────────────────────────────────────┐
# │                                     │
# │    👵 SOPHIA WITH PURSE 👜           │
# │                                     │
# │    "Picture it: Sicily, 1922..."    │
# │    [Gesturing dramatically]         │
# │                                     │
# └─────────────────────────────────────┘
# ```

# %%
# Example (commented out): generate Sophia image
# generate_stability_image(
#     "Comic-book style illustration of Sophia Petrillo gesturing with her purse, telling a dramatic story, warm kitchen lighting, playful mood",
#     "images/sophia_story.png"
# )

# %% [markdown]
# ---
#
# ## 🏠 Act 2: Blanche Gets Technical
#
# *[INT. LIVING ROOM - AFTERNOON]*
#
# *Blanche enters in a glamorous outfit, carrying a tablet.*
#
# **BLANCHE:** "Well, Dorothy, I heard you're having trouble with that npm thing. You know, I dated a software developer once. Twice. Okay, seven times. Anyway, he taught me all about package management."
#
# **DOROTHY:** "Blanche, you know about npm?"
#
# **BLANCHE:** "Honey, I know about a lot of things. Now, let me show you how to get started."

# %% [markdown]
# ### 📸 Character Image Placeholder: Blanche Looking Glamorous
#
# *[Comic-style image will appear here: Blanche Devereaux in elegant attire, holding a tablet, winking]*
#
# ```
# ┌─────────────────────────────────────┐
# │                                     │
# │    💃 BLANCHE WITH TABLET 📱         │
# │                                     │
# │    "I know about packages, honey"   │
# │    [Confident smile]                │
# │                                     │
# └─────────────────────────────────────┘
# ```

# %%
# Example (commented out): generate Blanche image
# generate_stability_image(
#     "Comic-book style illustration of Blanche Devereaux in glamorous outfit holding a tablet, confident smile, Miami sunset colors",
#     "images/blanche_glamorous.png"
# )

# %% [markdown]
# ## 🚀 Getting Started with npm
#
# First, let's check if npm is installed on your system:

# %%
# Check npm version
# (This is a demonstration - in a real Jupyter notebook with Node.js kernel)

# Run this in your terminal:
# npm --version

# For this Python notebook, we'll simulate the output:
print("npm version check:")
print("$ npm --version")
print("10.5.0")
print("\n✅ npm is installed!")

# %% [markdown]
# ## 🎬 Creating Your First Project
#
# **BLANCHE:** "Now, sugar, every npm project starts with a `package.json` file. Think of it as your little black book of dependencies."
#
# **DOROTHY:** "Blanche!"
#
# **BLANCHE:** "What? It keeps track of all the packages your project needs, just like I keep track of... never mind."

# %%
# Initialize a new npm project
# In your terminal, you would run:
# npm init -y

# This creates a package.json file with default values

import json

# Example package.json file
package_json_example = {
    "name": "golden-girls-retirement-website",
    "version": "1.0.0",
    "description": "A website for our retirement community",
    "main": "index.js",
    "scripts": {
        "test": "echo \"Error: no test specified\" && exit 1"
    },
    "keywords": ["retirement", "community", "miami"],
    "author": "Dorothy Zbornak",
    "license": "ISC"
}

print("📄 Example package.json:")
print(json.dumps(package_json_example, indent=2))

# %% [markdown]
# ---
#
# ## 🏠 Act 3: Rose's Simple Explanations
#
# *[INT. KITCHEN - LATER]*
#
# **ROSE:** "You know, Dorothy, installing packages is just like when we organized the bake sale in St. Olaf."
#
# **DOROTHY:** "Rose, I swear if you tell another St. Olaf story—"
#
# **ROSE:** "No, listen! When we needed ingredients, we'd go to different shops. npm install is like going to the shop and bringing the ingredients home. Then everyone in town could use them!"
#
# **DOROTHY:** "Rose, that's... actually a good analogy."
#
# **ROSE:** "Really?"
#
# **DOROTHY:** "Don't let it go to your head."

# %% [markdown]
# ### 📸 Character Image Placeholder: Rose Being Innocent
#
# *[Comic-style image will appear here: Rose Nylund smiling sweetly, looking pleased with herself]*
#
# ```
# ┌─────────────────────────────────────┐
# │                                     │
# │    👱‍♀️ ROSE SMILING 😊               │
# │                                     │
# │    "Just like St. Olaf!"            │
# │    [Innocent expression]            │
# │                                     │
# └─────────────────────────────────────┘
# ```

# %%
# Example (commented out): generate Rose image
# generate_stability_image(
#     "Comic-book style illustration of Rose Nylund smiling innocently, soft pastel colors, cozy kitchen background",
#     "images/rose_innocent.png"
# )

# %% [markdown]
# ## 📥 Installing Packages
#
# There are several ways to install packages with npm:

# %%
# Installing packages - Command examples

examples = {
    "Install a package locally": "npm install express",
    "Install as a dev dependency": "npm install --save-dev jest",
    "Install globally": "npm install -g create-react-app",
    "Install specific version": "npm install lodash@4.17.21",
    "Install all dependencies from package.json": "npm install"
}

print("📦 npm Installation Commands:\n")
for description, command in examples.items():
    print(f"▶ {description}:")
    print(f"  $ {command}\n")

# %% [markdown]
# ## 🌳 Dependency Trees and `node_modules`
#
# **DOROTHY:** "Why is my `node_modules` folder the size of the Miami phone book?"
#
# **SOPHIA:** "Because every package brings its cousins. That's a dependency tree — and in 2026, even the trees need cable."

# %%
# Visualizing a dependency tree (example output)

dep_tree = (
    "my-app\n"
    "├── express@4.18.2\n"
    "│   ├── accepts@1.3.8\n"
    "│   ├── body-parser@1.20.1\n"
    "│   └── send@0.18.0\n"
    "├── react@18.2.0\n"
    "│   ├── loose-envify@1.4.0\n"
    "│   └── scheduler@0.23.0\n"
    "└── axios@1.4.0\n"
    "    └── follow-redirects@1.15.2\n"
    ""
)

print(dep_tree)

# %% [markdown]
# ### 🔒 `package-lock.json` in Plain English
#
# **BLANCHE:** "Dorothy, `package-lock.json` is like my date book — it freezes the exact versions so no surprises show up at the door."
#
# It records the **exact** versions installed, ensuring everyone gets the same dependency tree.

# %% [markdown]
# ## 📊 Dependencies vs. DevDependencies
#
# **SOPHIA:** "Let me break it down for you, Dorothy."
#
# - **Dependencies**: Packages your app needs to RUN (like flour for making bread)
# - **DevDependencies**: Packages you only need for DEVELOPMENT (like the recipe book - you don't serve it with the bread!)

# %%
# Example package.json with dependencies

package_with_deps = {
    "name": "golden-girls-retirement-website",
    "version": "1.0.0",
    "dependencies": {
        "express": "^4.18.2",          # Web framework - needed to run
        "react": "^18.2.0",            # UI library - needed to run
        "axios": "^1.4.0"              # HTTP client - needed to run
    },
    "devDependencies": {
        "jest": "^29.5.0",             # Testing framework - only for development
        "eslint": "^8.42.0",           # Linter - only for development
        "webpack": "^5.88.0"           # Bundler - only for development
    }
}

print("📄 Package.json with Dependencies:\n")
print(json.dumps(package_with_deps, indent=2))

# %% [markdown]
# ---
#
# ## 🏠 Act 4: The Crisis!
#
# *[INT. LIVING ROOM - EVENING]*
#
# **DOROTHY:** "Oh no! I installed the wrong version of a package and now nothing works!"
#
# **BLANCHE:** "Don't panic, honey. We can uninstall it."
#
# **ROSE:** "Is this like when I accidentally planted kudzu in the garden?"
#
# **DOROTHY:** "Rose, that destroyed the entire backyard!"
#
# **SOPHIA:** "And this is why we have the uninstall command, Dorothy. Show her, Blanche."

# %% [markdown]
# ### 📸 Character Image Placeholder: All Four Girls in Crisis Mode
#
# *[Comic-style image will appear here: All four Golden Girls gathered around laptop, looking concerned]*
#
# ```
# ┌─────────────────────────────────────┐
# │                                     │
# │    👵👱‍♀️💃🧑‍🦳 THE GIRLS 💻           │
# │                                     │
# │    [All looking at laptop]          │
# │    "We can fix this together!"      │
# │                                     │
# └─────────────────────────────────────┘
# ```

# %%
# Example (commented out): generate group crisis image
# generate_stability_image(
#     "Comic-book style illustration of all four Golden Girls crowding around a laptop, worried expressions, evening living room scene",
#     "images/girls_crisis.png"
# )

# %% [markdown]
# ## 🗑️ Managing Packages
#
# Sometimes you need to remove or update packages:

# %%
# Package management commands

management_commands = {
    "Uninstall a package": "npm uninstall express",
    "Update a specific package": "npm update express",
    "Update all packages": "npm update",
    "Check for outdated packages": "npm outdated",
    "List installed packages": "npm list",
    "List top-level packages only": "npm list --depth=0",
    "Clean cache (advanced troubleshooting; use sparingly, see npm docs)": "npm cache clean --force"
}

print("🔧 Package Management Commands:\n")
for description, command in management_commands.items():
    print(f"▶ {description}:")
    print(f"  $ {command}\n")

# %% [markdown]
# ---
#
# ## 🏠 Act 5: Scripts and Automation
#
# **BLANCHE:** "Now, Dorothy, let me tell you about the most powerful feature - npm scripts."
#
# **DOROTHY:** "I'm almost afraid to ask."
#
# **BLANCHE:** "Think of them as your little helpers. Instead of typing long commands every time, you create shortcuts in your package.json."
#
# **ROSE:** "Like speed dial!"
#
# **DOROTHY:** "Rose, that's actually correct."
#
# **SOPHIA:** "Even a broken clock is right twice a day."
# *Dorothy whispers:* "If only Congress had `npm run lint`, we might catch errors before production."

# %% [markdown]
# ## ⚡ npm Scripts
#
# npm scripts are custom commands you can define in your package.json file:

# %%
# Example package.json with useful scripts

package_with_scripts = {
    "name": "golden-girls-retirement-website",
    "version": "1.0.0",
    "scripts": {
        "start": "node server.js",                          # Start the application
        "dev": "nodemon server.js",                        # Start with auto-reload
        "test": "jest",                                    # Run tests
        "test:watch": "jest --watch",                      # Run tests in watch mode
        "build": "webpack --mode production",              # Build for production
        "lint": "eslint .",                                # Check code quality
        "lint:fix": "eslint . --fix",                      # Fix code quality issues
        "clean": "rm -rf dist node_modules",               # Clean build artifacts
        "deploy": "npm run build && npm run upload"        # Chain multiple commands
    }
}

print("⚡ Package.json with Scripts:\n")
print(json.dumps(package_with_scripts, indent=2))
print("\n🏃 To run a script, use: npm run <script-name>")
print("   Example: npm run dev")

# %% [markdown]
# ## 🔍 Understanding Version Numbers (Semantic Versioning)
#
# **SOPHIA:** "Pay attention, Dorothy. This is important."
#
# Version numbers in npm follow the format: **MAJOR.MINOR.PATCH**
#
# - **MAJOR** (1.0.0): Breaking changes - like changing the recipe entirely
# - **MINOR** (0.1.0): New features - like adding chocolate chips to cookies
# - **PATCH** (0.0.1): Bug fixes - like fixing a typo in the recipe
#
# **Special Symbols:**
# - **^1.2.3** - Compatible with 1.2.3, allows MINOR and PATCH updates (1.x.x)
# - **~1.2.3** - Approximately 1.2.3, allows only PATCH updates (1.2.x)
# - **1.2.3** - Exactly version 1.2.3
#
# *2026 joke: Trump's press releases have more MAJOR versions than Miami has humidity warnings.*

# %%
# Semantic versioning examples

versioning_examples = {
    "^1.2.3": "Allows: 1.2.3, 1.2.4, 1.3.0, 1.9.9 | Blocks: 2.0.0",
    "~1.2.3": "Allows: 1.2.3, 1.2.4, 1.2.9 | Blocks: 1.3.0, 2.0.0",
    "1.2.3": "Allows: Only 1.2.3 exactly",
    "*": "Allows: Any version (not recommended!)",
    ">=1.2.3": "Allows: 1.2.3 and any higher version",
    "1.2.x": "Allows: 1.2.0, 1.2.1, etc. | Blocks: 1.3.0"
}

print("📊 Semantic Versioning Guide:\n")
for version, description in versioning_examples.items():
    print(f"▶ {version:12} → {description}")

# %% [markdown]
# ---
#
# ## 🏠 Act 6: The Resolution
#
# *[INT. KITCHEN - NEXT MORNING]*
#
# **DOROTHY:** "I did it! The retirement community website is up and running! And I used npm to manage all the packages!"
#
# **ROSE:** "Oh Dorothy, I'm so proud of you!"
#
# **BLANCHE:** "See? I told you it wasn't that hard once you understand it."
#
# **SOPHIA:** "And the best part? You didn't have to write everything from scratch. Just like my cannoli story!"
#
# **DOROTHY:** "You know what, Ma? Your Sicily story actually helped. Thank you, all of you."
#
# **ROSE:** "Group hug!"
#
# **DOROTHY:** "Rose, no—"
#
# *[They all hug]*
#
# **SOPHIA:** "Now can we eat? All this coding made me hungry."
#
# **BLANCHE:** "I'll make reservations at that new Italian place."
#
# **DOROTHY:** "Using npm is like having good friends - they help you do things you couldn't do alone."
#
# **ROSE:** "That's beautiful, Dorothy."
#
# **SOPHIA:** "It's also how we got through installing that security update last week."
#
# **ALL:** *[Laughter]*
#
# **THE END**
#
# *[No cliffhangers! Granny Ethel approves! ✅]*

# %% [markdown]
# ### 📸 Character Image Placeholder: Happy Ending
#
# *[Comic-style image will appear here: All four Golden Girls celebrating around the laptop with cheesecake]*
#
# ```
# ┌─────────────────────────────────────┐
# │                                     │
# │    🎉 THE GOLDEN GIRLS 🎊            │
# │                                     │
# │    [All smiling, eating cheesecake] │
# │    "We did it together!" 🍰         │
# │                                     │
# └─────────────────────────────────────┘
# ```

# %%
# Example (commented out): generate happy ending image
# generate_stability_image(
#     "Comic-book style illustration of all four Golden Girls celebrating with cheesecake around a laptop, joyful expressions, bright celebratory colors",
#     "images/girls_happy_ending.png"
# )

# %% [markdown]
# ---
#
# ## 📚 Quick Reference Guide
#
# ### Essential npm Commands (Dorothy's Cheat Sheet)
#
# | Command | Description | When to Use |
# |---------|-------------|-------------|
# | `npm init` | Create a new project | Starting a new project |
# | `npm init -y` | Create with defaults | Quick project setup |
# | `npm install <package>` | Install a package | Adding functionality |
# | `npm install` | Install all dependencies | After cloning a project |
# | `npm uninstall <package>` | Remove a package | Cleaning up |
# | `npm update` | Update packages | Keeping things current |
# | `npm run <script>` | Run a script | Executing custom commands |
# | `npm list` | Show installed packages | Checking what's installed |
# | `npm outdated` | Check for updates | Finding old packages |
# | `npm audit` | Security check | Finding vulnerabilities |
# | `npm audit fix` | Fix security issues | Patching vulnerabilities |

# %%
# Practical Example: Setting up a real project

print("🏗️ Setting Up a Real Project - Step by Step:\n")
print("1️⃣ Create project directory:")
print("   $ mkdir my-awesome-project")
print("   $ cd my-awesome-project")
print()
print("2️⃣ Initialize npm:")
print("   $ npm init -y")
print()
print("3️⃣ Install dependencies:")
print("   $ npm install express")
print("   $ npm install --save-dev nodemon")
print()
print("4️⃣ Create your main file:")
print("   $ touch index.js")
print()
print("5️⃣ Add scripts to package.json:")
print('   "scripts": {')
print('     "start": "node index.js",')
print('     "dev": "nodemon index.js"')
print('   }')
print()
print("6️⃣ Start developing:")
print("   $ npm run dev")
print()
print("✅ You're ready to code!")

# %% [markdown]
# ## 🎓 Key Takeaways (What Dorothy Learned)
#
# 1. **npm is a package manager** - It helps you use and manage code libraries
# 2. **package.json is your project's blueprint** - It lists all dependencies and settings
# 3. **Dependencies are needed for production** - Your app needs these to run
# 4. **DevDependencies are for development only** - Testing, linting, building tools
# 5. **npm scripts automate common tasks** - Like shortcuts for complex commands
# 6. **Semantic versioning matters** - Understand ^, ~, and exact versions
# 7. **Always run `npm install`** - After cloning or pulling a project
# 8. **Use `npm audit`** - To check for security vulnerabilities
# 9. **Read the documentation** - Every package has docs on npmjs.com
# 10. **Don't commit node_modules** - Add it to .gitignore!
#
# ---
#
# ## 🌟 Bonus: Common Issues and Solutions
#
# **SOPHIA'S TROUBLESHOOTING TIPS:**
#
# | Problem | Solution | Sophia Says |
# |---------|----------|-------------|
# | "Module not found" | Run `npm install` | "You forgot the ricotta!" |
# | Permission errors | Use `sudo` (carefully!) or fix npm permissions | "Ask nicely first" |
# | Weird caching issues | `npm cache clean --force` | "When in doubt, clean it out" |
# | Package conflicts | Delete `node_modules`, run `npm install` | "Start fresh, like my second marriage" |
# | Outdated packages | `npm update` | "Everything needs a refresh" |
# | Security warnings | `npm audit fix` | "Safety first, pussycat" |

# %%
# Final wisdom from the Golden Girls

wisdom = {
    "Dorothy": "npm is like teaching - you build on what others have created.",
    "Rose": "Just like St. Olaf's community barn raising, everyone contributes!",
    "Blanche": "Good dependencies are like good company - choose wisely.",
    "Sophia": "Picture it: You, tomorrow, knowing npm. Now go build something!"
}

print("💎 Golden Girls Wisdom on npm:\n")
for character, quote in wisdom.items():
    print(f"{character}: \"{quote}\"\n")

print("\n🎬 Thank you for being a friend! Happy coding! 🎬")

# %% [markdown]
# ---
#
# ## 🧁 Mini Quiz: Golden Girls Edition
#
# **1) Dorothy says:** Which file is the "blueprint" of your project?
# - A) `golden_girls.md`
# - B) `package.json`
# - C) `cheesecake.txt`
#
# **2) Rose says:** If you only want bug fixes, which version range do you use?
# - A) `^1.2.3`
# - B) `~1.2.3`
# - C) `*`
#
# **3) Blanche says:** Which command runs your custom scripts?
# - A) `npm sprint`
# - B) `npm run <script>`
# - C) `npm glam`
#
# **4) Sophia says:** What file locks the dependency tree?
# - A) `package-lock.json`
# - B) `lock-it-up.json`
# - C) `sophia_story.txt`
#
# **Answers:** 1) B · 2) B · 3) B · 4) A

# %% [markdown]
# ---
#
# ## 🎨 Note About Images
#
# This notebook includes placeholders for comic-style character images. You can use the Stability AI API key you entered at the beginning to generate these images using their API. Each placeholder shows where a character image would appear in the story.
#
# To generate images, you would use the Stability AI API with prompts like:
# - "Comic-style illustration of Dorothy Zbornak looking confused at laptop"
# - "Comic-style illustration of Sophia Petrillo telling a story dramatically"
# - "Comic-style illustration of Blanche Devereaux looking glamorous with tablet"
# - "Comic-style illustration of Rose Nylund smiling innocently"
# - "Comic-style illustration of all four Golden Girls celebrating together"
#
# *The API key is stored but not used in this educational notebook - you can implement the image generation as an extension exercise!*

# %% [markdown]
# ---
#
# ## 📖 Further Learning Resources
#
# - **Official npm Documentation**: https://docs.npmjs.com/
# - **npm Registry**: https://www.npmjs.com/
# - **Node.js Documentation**: https://nodejs.org/docs/
# - **Semantic Versioning**: https://semver.org/
# - **package.json Guide**: https://docs.npmjs.com/cli/v9/configuring-npm/package-json
#
# ---
#
# *Created with love and cheesecake* 🍰
#
# *This tutorial is dedicated to all the Golden Girls fans who never thought they'd learn about package management through their favorite sitcom.* ❤️
#
# **Remember: "Thank you for being a friend!" extends to the npm community too!** 🌟
